# %%
import pandas as pd
import matplotlib.pyplot as plt

d = pd.read_excel("./sample.xls", parse_dates=["Date"])
df = pd.DataFrame(d)
df.plot()
plt.show()
df
# Out:
#   First Name  Last Name  Gender        Country  Age       Date      Id
# 0      Dulce      Abril  Female  United States   32 2017-10-15  1562.0
# 1       Mara  Hashimoto     NaN  Great Britain   70 2016-08-16  1582.0
# 2     Philip       Gent    Male         France   36 2015-05-21     NaN
# 3   Kathleen     Hanner  Female  United States   25 2017-10-15  3549.0
# 4    Nereida        NaN  Female            NaN   58 2016-08-16  2468.0
# 5        NaN      Brumm    Male  United States   80        NaT  2554.0
# 6       Etta       Hurn  Female  Great Britain   56 2017-10-15     NaN
# 7    Earlean     Melgar  Female  United States   27 2016-08-16  2456.0
# 8   Vincenza    Weiland  Female  United States   40 2015-05-21  6548.0

# %%
df
# Out:
#      0 First Name  Last Name  Gender        Country  Age       Date    Id
# 0    1      Dulce      Abril  Female  United States   32 2017-10-15  1562
# 1    2       Mara  Hashimoto  Female  Great Britain   25 2016-08-16  1582
# 2    3     Philip       Gent    Male         France   36 2015-05-21  2587
# 3    4   Kathleen     Hanner  Female  United States   25 2017-10-15  3549
# 4    5    Nereida    Magwood  Female  United States   58 2016-08-16  2468
# 5    6     Gaston      Brumm    Male  United States   24 2015-05-21  2554
# 6    7       Etta       Hurn  Female  Great Britain   56 2017-10-15  3598
# 7    8    Earlean     Melgar  Female  United States   27 2016-08-16  2456
# 8    9   Vincenza    Weiland  Female  United States   40 2015-05-21  6548
# 9   10      Dulce      Abril  Female  United States   33 2018-10-15  1563
# 10  11       Mara  Hashimoto  Female  Great Britain   26 2017-08-16  1583
# 11  12     Philip       Gent    Male         France   37 2016-05-21  2588
# ...

# %%
df = pd.read_csv(

    'https://raw.github.com/pandas-dev/'

    'pandas/main/pandas/tests/io/data/csv/iris.csv'

)

pd.plotting.andrews_curves(df, 'Name')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_excel("./sample.xls")
df = pd.DataFrame(data)
plt.plot( df.Country, df.Age)
plt.legend() 
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = [1,2,6]
y = [1,4,9]
z = [10,7,3]
plt.plot(x,z,marker='o' ) # marker is used for better understanding of plotting
plt.plot(x,y) #x is for x-axis and y is for y-axis
#plt.plot(x,y, linestyle ="dotted")  this is used for dotted line plotting
plt.title("test plot") #title for plot
plt.xlabel("x label") # label for x axis
plt.ylabel("y label") # label for y axis
plt.legend(["this is z","this is y"]) #to make a better understanding
plt.grid() # used for grid layout while plotting
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])


plt.show()

# %%
data = pd.read_excel("./sample.xls")
df = pd.DataFrame(data)
plt.plot( df.Id, df.Age)
plt.show()

# %%
data = pd.read_excel("./sample.xls")
df = pd.DataFrame(data)
df.plot()
# Out:
# <AxesSubplot:>

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)


plt.show()
